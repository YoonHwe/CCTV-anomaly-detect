# %%
# JSON 파일 경로 모음
json_file_path_list = ['/Users/heoyoonhwe/2022IR/C011_A01_SY07_P06_S03_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A01_SY07_P06_S04_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A01_SY07_P06_S04_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A01_SY07_P06_S04_02DAS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A01_SY07_P06_S04_02DBS.json',

                       '/Users/heoyoonhwe/2022IR/C011_A05_SY13_P07_S20_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A05_SY13_P07_S20_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A05_SY13_P07_S20_02DAS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A05_SY13_P07_S20_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C011_A05_SY13_P07_S20_03DAS.json',

                       '/Users/heoyoonhwe/2022IR/C012_A02_SY10_P07_S01_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A02_SY10_P07_S01_03DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A02_SY10_P07_S01_03DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A02_SY10_P07_S02_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A02_SY10_P07_S02_01DBS.json',

                       '/Users/heoyoonhwe/2022IR/C012_A03_SY10_P07_S01_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A03_SY10_P07_S01_03DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A03_SY10_P07_S01_03DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A03_SY10_P07_S01_04DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A03_SY10_P07_S01_04DBS.json',

                       '/Users/heoyoonhwe/2022IR/C012_A04_SY10_P07_S01_02DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A04_SY10_P07_S01_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A04_SY10_P07_S01_03DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A04_SY10_P07_S01_03DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A04_SY10_P07_S02_01DAS.json',

                       '/Users/heoyoonhwe/2022IR/C012_A06_SY13_P07_S20_09DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A06_SY13_P07_S20_10DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A06_SY13_P07_S20_10DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A06_SY13_P07_S20_11DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A06_SY13_P07_S20_11DBS.json',

                       '/Users/heoyoonhwe/2022IR/C012_A07_SY13_P07_S20_05DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A07_SY13_P07_S20_05DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A07_SY13_P07_S20_06DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A07_SY13_P07_S20_06DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A07_SY13_P07_S21_01DAS.json',

                       '/Users/heoyoonhwe/2022IR/C012_A08_SY13_P07_S20_09DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A08_SY13_P07_S20_10DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A08_SY13_P07_S20_10DBS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A08_SY13_P07_S20_11DAS.json',
                       '/Users/heoyoonhwe/2022IR/C012_A08_SY13_P07_S20_11DBS.json',

                       '/Users/heoyoonhwe/2022IR/C021_A17_SY32_P01_S11_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A17_SY32_P01_S12_01NAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A17_SY32_P01_S12_01NBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A17_SY32_P01_S13_01NBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A17_SY32_P07_S08_01DAS.json',

                       '/Users/heoyoonhwe/2022IR/C021_A18_SY32_P01_S10_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A18_SY32_P01_S11_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A18_SY32_P01_S11_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A18_SY32_P01_S11_02DAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A18_SY32_P01_S11_02DBS.json',

                       '/Users/heoyoonhwe/2022IR/C021_A19_SY32_P01_S11_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A19_SY32_P01_S11_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A19_SY32_P01_S12_01NAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A19_SY32_P01_S12_01NBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A19_SY32_P01_S13_01NAS.json',

                       '/Users/heoyoonhwe/2022IR/C021_A20_SY32_P07_S10_03DAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A20_SY32_P07_S10_03DBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A20_SY32_P07_S11_01NAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A20_SY32_P07_S12_01NAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A20_SY32_P07_S12_01NBS.json',

                       '/Users/heoyoonhwe/2022IR/C021_A21_SY32_P07_S08_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A21_SY32_P07_S08_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A21_SY32_P07_S09_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A21_SY32_P07_S10_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C021_A21_SY32_P07_S10_01DBS.json',

                       '/Users/heoyoonhwe/2022IR/C031_A22_SY23_P06_S12_06DAS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A22_SY23_P06_S12_06DBS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A22_SY23_P06_S13_04DAS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A22_SY23_P06_S13_04DBS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A22_SY23_P06_S13_05DAS.json',

                       '/Users/heoyoonhwe/2022IR/C031_A23_SY23_P06_S07_08DBS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A23_SY23_P06_S07_09DAS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A23_SY23_P06_S07_09DBS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A23_SY23_P06_S08_07DAS.json',
                       '/Users/heoyoonhwe/2022IR/C031_A23_SY23_P06_S08_07DBS.json',

                       '/Users/heoyoonhwe/2022IR/C032_A24_SY23_P06_S12_03DAS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A24_SY23_P06_S12_03DBS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A24_SY23_P07_S01_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A24_SY23_P07_S01_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A24_SY23_P07_S02_01DAS.json',

                       '/Users/heoyoonhwe/2022IR/C032_A25_SY32_P05_S03_01DAS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A25_SY32_P05_S03_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A25_SY32_P05_S03_02DAS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A25_SY32_P05_S03_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A25_SY32_P05_S03_03DAS.json',

                       '/Users/heoyoonhwe/2022IR/C032_A26_SY32_P06_S06_01DBS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A26_SY32_P06_S06_02DAS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A26_SY32_P06_S06_03DAS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A26_SY32_P06_S06_03DBS.json',
                       '/Users/heoyoonhwe/2022IR/C032_A26_SY32_P06_S07_01DAS.json',

                       '/Users/heoyoonhwe/2022IR/C041_A30_SY32_P07_S08_01NBS.json',
                       '/Users/heoyoonhwe/2022IR/C041_A30_SY32_P07_S08_02NAS.json',
                       '/Users/heoyoonhwe/2022IR/C041_A30_SY32_P07_S08_02NBS.json',
                       '/Users/heoyoonhwe/2022IR/C041_A30_SY32_P07_S08_03NAS.json',
                       '/Users/heoyoonhwe/2022IR/C041_A30_SY32_P07_S08_03NBS.json',

                       '/Users/heoyoonhwe/2022IR/C042_A31_SY32_P09_S04_02DBS.json',
                       '/Users/heoyoonhwe/2022IR/C042_A31_SY32_P09_S06_01NAS.json',
                       '/Users/heoyoonhwe/2022IR/C042_A31_SY32_P09_S06_01NBS.json',
                       '/Users/heoyoonhwe/2022IR/C042_A31_SY32_P09_S06_02NAS.json',
                       '/Users/heoyoonhwe/2022IR/C042_A31_SY32_P09_S06_02NBS.json',
                       ]
len(json_file_path_list)
# Out:
# 100

# %% [markdown]
# train, test set 분리(test_size = 0.2)

# %%
import copy
import numpy as np
raw_data_X_path_list = copy.deepcopy(json_file_path_list)
raw_data_Y_path_list = copy.deepcopy(json_file_path_list)
for i in range(len(json_file_path_list)):
  string = copy.deepcopy(json_file_path_list[i])
  string = string.replace('/Users/heoyoonhwe/2022IR/', '/Users/heoyoonhwe/2022IR/dataset/raw_data_X_')
  string = string.replace('.json', '.npy')
  raw_data_X_path_list[i] = string
  string = string.replace('X', 'Y')
  raw_data_Y_path_list[i] = string

print(np.shape(raw_data_X_path_list))
print(np.shape(raw_data_Y_path_list))
# Out:
# (100,)
# (100,)

# %%
raw_data_X_train_length = 0
raw_data_X_test_length = 0

for i in range(len(raw_data_X_path_list)):
  raw_data_X_each = np.load(raw_data_X_path_list[i])
  if(i % 5 != 4):
    raw_data_X_train_length += (np.shape(raw_data_X_each)[0])
  else:
    raw_data_X_test_length += (np.shape(raw_data_X_each)[0])
print(raw_data_X_train_length)
print(raw_data_X_test_length)
# Out:
# 280076
# 70018

# %%
raw_data_X_test = np.concatenate([ 
  np.load(raw_data_X_path_list[4]),
  np.load(raw_data_X_path_list[9]),
  np.load(raw_data_X_path_list[14]),
  np.load(raw_data_X_path_list[19]),
  np.load(raw_data_X_path_list[24]),
  np.load(raw_data_X_path_list[29]),
  np.load(raw_data_X_path_list[34]),
  np.load(raw_data_X_path_list[39]),
  np.load(raw_data_X_path_list[44]),
  np.load(raw_data_X_path_list[49]),
  np.load(raw_data_X_path_list[54]),
  np.load(raw_data_X_path_list[59]),
  np.load(raw_data_X_path_list[64]),
  np.load(raw_data_X_path_list[69]),
  np.load(raw_data_X_path_list[74]),
  np.load(raw_data_X_path_list[79]),
  np.load(raw_data_X_path_list[84]),
  np.load(raw_data_X_path_list[89]),
  np.load(raw_data_X_path_list[94]),
  np.load(raw_data_X_path_list[99]),
], axis=0)

raw_data_Y_test = np.concatenate([ 
  np.load(raw_data_Y_path_list[4]),
  np.load(raw_data_Y_path_list[9]),
  np.load(raw_data_Y_path_list[14]),
  np.load(raw_data_Y_path_list[19]),
  np.load(raw_data_Y_path_list[24]),
  np.load(raw_data_Y_path_list[29]),
  np.load(raw_data_Y_path_list[34]),
  np.load(raw_data_Y_path_list[39]),
  np.load(raw_data_Y_path_list[44]),
  np.load(raw_data_Y_path_list[49]),
  np.load(raw_data_Y_path_list[54]),
  np.load(raw_data_Y_path_list[59]),
  np.load(raw_data_Y_path_list[64]),
  np.load(raw_data_Y_path_list[69]),
  np.load(raw_data_Y_path_list[74]),
  np.load(raw_data_Y_path_list[79]),
  np.load(raw_data_Y_path_list[84]),
  np.load(raw_data_Y_path_list[89]),
  np.load(raw_data_Y_path_list[94]),
  np.load(raw_data_Y_path_list[99]),
], axis=0)

# %%
print(np.shape(raw_data_X_test), np.shape(raw_data_Y_test))
# Out:
# (70018, 100, 48) (70018, 100, 1)

# %%
raw_data_X_train = np.concatenate([ 
  np.load(raw_data_X_path_list[0]),
  np.load(raw_data_X_path_list[1]),
  np.load(raw_data_X_path_list[2]),
  np.load(raw_data_X_path_list[3]),
  np.load(raw_data_X_path_list[5]),
  np.load(raw_data_X_path_list[6]),
  np.load(raw_data_X_path_list[7]),
  np.load(raw_data_X_path_list[8]),
  np.load(raw_data_X_path_list[10]),
  np.load(raw_data_X_path_list[11]),
  np.load(raw_data_X_path_list[12]),
  np.load(raw_data_X_path_list[13]),
  np.load(raw_data_X_path_list[15]),
  np.load(raw_data_X_path_list[16]),
  np.load(raw_data_X_path_list[17]),
  np.load(raw_data_X_path_list[18]),
  np.load(raw_data_X_path_list[20]),
  np.load(raw_data_X_path_list[21]),
  np.load(raw_data_X_path_list[22]),
  np.load(raw_data_X_path_list[23]),
  np.load(raw_data_X_path_list[25]),
  np.load(raw_data_X_path_list[26]),
  np.load(raw_data_X_path_list[27]),
  np.load(raw_data_X_path_list[28]),
  np.load(raw_data_X_path_list[30]),
  np.load(raw_data_X_path_list[31]),
  np.load(raw_data_X_path_list[32]),
  np.load(raw_data_X_path_list[33]),
  np.load(raw_data_X_path_list[35]),
  np.load(raw_data_X_path_list[36]),
  np.load(raw_data_X_path_list[37]),
  np.load(raw_data_X_path_list[38]),
  np.load(raw_data_X_path_list[40]),
  np.load(raw_data_X_path_list[41]),
  np.load(raw_data_X_path_list[42]),
  np.load(raw_data_X_path_list[43]),
  np.load(raw_data_X_path_list[45]),
  np.load(raw_data_X_path_list[46]),
  np.load(raw_data_X_path_list[47]),
  np.load(raw_data_X_path_list[48]),
  np.load(raw_data_X_path_list[50]),
  np.load(raw_data_X_path_list[51]),
  np.load(raw_data_X_path_list[52]),
  np.load(raw_data_X_path_list[53]),
  np.load(raw_data_X_path_list[55]),
  np.load(raw_data_X_path_list[56]),
  np.load(raw_data_X_path_list[57]),
  np.load(raw_data_X_path_list[58]),
  np.load(raw_data_X_path_list[60]),
  np.load(raw_data_X_path_list[61]),
  np.load(raw_data_X_path_list[62]),
  np.load(raw_data_X_path_list[63]),
  np.load(raw_data_X_path_list[65]),
  np.load(raw_data_X_path_list[66]),
  np.load(raw_data_X_path_list[67]),
  np.load(raw_data_X_path_list[68]),
  np.load(raw_data_X_path_list[70]),
  np.load(raw_data_X_path_list[71]),
  np.load(raw_data_X_path_list[72]),
  np.load(raw_data_X_path_list[73]),
  np.load(raw_data_X_path_list[75]),
  np.load(raw_data_X_path_list[76]),
  np.load(raw_data_X_path_list[77]),
  np.load(raw_data_X_path_list[78]),
  np.load(raw_data_X_path_list[80]),
  np.load(raw_data_X_path_list[81]),
  np.load(raw_data_X_path_list[82]),
  np.load(raw_data_X_path_list[83]),
  np.load(raw_data_X_path_list[85]),
  np.load(raw_data_X_path_list[86]),
  np.load(raw_data_X_path_list[87]),
  np.load(raw_data_X_path_list[88]),
  np.load(raw_data_X_path_list[90]),
  np.load(raw_data_X_path_list[91]),
  np.load(raw_data_X_path_list[92]),
  np.load(raw_data_X_path_list[93]),
  np.load(raw_data_X_path_list[95]),
  np.load(raw_data_X_path_list[96]),
  np.load(raw_data_X_path_list[97]),
  np.load(raw_data_X_path_list[98])
], axis=0)

raw_data_Y_train = np.concatenate([ 
  np.load(raw_data_Y_path_list[0]),
  np.load(raw_data_Y_path_list[1]),
  np.load(raw_data_Y_path_list[2]),
  np.load(raw_data_Y_path_list[3]),
  np.load(raw_data_Y_path_list[5]),
  np.load(raw_data_Y_path_list[6]),
  np.load(raw_data_Y_path_list[7]),
  np.load(raw_data_Y_path_list[8]),
  np.load(raw_data_Y_path_list[10]),
  np.load(raw_data_Y_path_list[11]),
  np.load(raw_data_Y_path_list[12]),
  np.load(raw_data_Y_path_list[13]),
  np.load(raw_data_Y_path_list[15]),
  np.load(raw_data_Y_path_list[16]),
  np.load(raw_data_Y_path_list[17]),
  np.load(raw_data_Y_path_list[18]),
  np.load(raw_data_Y_path_list[20]),
  np.load(raw_data_Y_path_list[21]),
  np.load(raw_data_Y_path_list[22]),
  np.load(raw_data_Y_path_list[23]),
  np.load(raw_data_Y_path_list[25]),
  np.load(raw_data_Y_path_list[26]),
  np.load(raw_data_Y_path_list[27]),
  np.load(raw_data_Y_path_list[28]),
  np.load(raw_data_Y_path_list[30]),
  np.load(raw_data_Y_path_list[31]),
  np.load(raw_data_Y_path_list[32]),
  np.load(raw_data_Y_path_list[33]),
  np.load(raw_data_Y_path_list[35]),
  np.load(raw_data_Y_path_list[36]),
  np.load(raw_data_Y_path_list[37]),
  np.load(raw_data_Y_path_list[38]),
  np.load(raw_data_Y_path_list[40]),
  np.load(raw_data_Y_path_list[41]),
  np.load(raw_data_Y_path_list[42]),
  np.load(raw_data_Y_path_list[43]),
  np.load(raw_data_Y_path_list[45]),
  np.load(raw_data_Y_path_list[46]),
  np.load(raw_data_Y_path_list[47]),
  np.load(raw_data_Y_path_list[48]),
  np.load(raw_data_Y_path_list[50]),
  np.load(raw_data_Y_path_list[51]),
  np.load(raw_data_Y_path_list[52]),
  np.load(raw_data_Y_path_list[53]),
  np.load(raw_data_Y_path_list[55]),
  np.load(raw_data_Y_path_list[56]),
  np.load(raw_data_Y_path_list[57]),
  np.load(raw_data_Y_path_list[58]),
  np.load(raw_data_Y_path_list[60]),
  np.load(raw_data_Y_path_list[61]),
  np.load(raw_data_Y_path_list[62]),
  np.load(raw_data_Y_path_list[63]),
  np.load(raw_data_Y_path_list[65]),
  np.load(raw_data_Y_path_list[66]),
  np.load(raw_data_Y_path_list[67]),
  np.load(raw_data_Y_path_list[68]),
  np.load(raw_data_Y_path_list[70]),
  np.load(raw_data_Y_path_list[71]),
  np.load(raw_data_Y_path_list[72]),
  np.load(raw_data_Y_path_list[73]),
  np.load(raw_data_Y_path_list[75]),
  np.load(raw_data_Y_path_list[76]),
  np.load(raw_data_Y_path_list[77]),
  np.load(raw_data_Y_path_list[78]),
  np.load(raw_data_Y_path_list[80]),
  np.load(raw_data_Y_path_list[81]),
  np.load(raw_data_Y_path_list[82]),
  np.load(raw_data_Y_path_list[83]),
  np.load(raw_data_Y_path_list[85]),
  np.load(raw_data_Y_path_list[86]),
  np.load(raw_data_Y_path_list[87]),
  np.load(raw_data_Y_path_list[88]),
  np.load(raw_data_Y_path_list[90]),
  np.load(raw_data_Y_path_list[91]),
  np.load(raw_data_Y_path_list[92]),
  np.load(raw_data_Y_path_list[93]),
  np.load(raw_data_Y_path_list[95]),
  np.load(raw_data_Y_path_list[96]),
  np.load(raw_data_Y_path_list[97]),
  np.load(raw_data_Y_path_list[98])
], axis=0)

# %%
print(np.shape(raw_data_X_train), np.shape(raw_data_Y_train))
# Out:
# (280076, 100, 48) (280076, 100, 1)

# %%
raw_data_Y_class = np.unique(raw_data_Y_train)
y_train_size = len(np.unique(raw_data_Y_train))

raw_data_Y_train_encoded = np.zeros([np.shape(raw_data_Y_train)[0], 100, y_train_size])
# print(np.shape(raw_data_Y_train_encoded))

for i in range(np.shape(raw_data_Y_train)[0]):
    if(i % 1000 == 0):
        print(i, " / ", np.shape(raw_data_Y_train)[0])
    for j in range(np.shape(raw_data_Y_train)[1]):
        for k in range(y_train_size):
            if(raw_data_Y_train[i][j][0] == raw_data_Y_class[k]):
                raw_data_Y_train_encoded[i][j][k] = 1
                break
# Out:
# 0  /  280076
# 1000  /  280076
# 2000  /  280076
# 3000  /  280076
# 4000  /  280076
# 5000  /  280076
# 6000  /  280076
# 7000  /  280076
# 8000  /  280076
# 9000  /  280076
# 10000  /  280076
# 11000  /  280076
# 12000  /  280076
# 13000  /  280076
# 14000  /  280076
# 15000  /  280076
# 16000  /  280076
# 17000  /  280076
# 18000  /  280076
# 19000  /  280076
# 20000  /  280076
# 21000  /  280076
# 22000  /  280076
# 23000  /  280076
# 24000  /  280076
# 25000  /  280076
# 26000  /  280076
# 27000  /  280076
# 28000  /  280076
# 29000  /  280076
# 30000  /  280076
# 31000  /  280076
# 32000  /  280076
# 33000  /  280076
# 34000  /  280076
# 35000  /  280076
# 36000  /  280076
# 37000  /  280076
# 38000  /  280076
# 39000  /  280076
# 40000  /  280076
# 41000  /  280076
# 42000  /  280076
# 43000  /  280076
# 44000  /  280076
# 45000  /  280076
# 46000  /  280076
# 47000  /  280076
# 48000  /  280076
# 49000  /  280076
# 50000  /  280076
# 51000  /  280076
# 52000  /  280076
# ...

# %%
raw_data_Y_class = np.unique(raw_data_Y_test)
y_test_size = len(np.unique(raw_data_Y_test))

raw_data_Y_test_encoded = np.zeros([np.shape(raw_data_Y_test)[0], 100, y_test_size])

for i in range(np.shape(raw_data_Y_test)[0]):
    if(i % 2000 == 0):
        print(i, " / ", np.shape(raw_data_Y_test)[0])
    for j in range(np.shape(raw_data_Y_test)[1]):
        for k in range(y_test_size):
            if(raw_data_Y_test[i][j][0] == raw_data_Y_class[k]):
                raw_data_Y_test_encoded[i][j][k] = 1
                break
# Out:
# 0  /  70018
# 2000  /  70018
# 4000  /  70018
# 6000  /  70018
# 8000  /  70018
# 10000  /  70018
# 12000  /  70018
# 14000  /  70018
# 16000  /  70018
# 18000  /  70018
# 20000  /  70018
# 22000  /  70018
# 24000  /  70018
# 26000  /  70018
# 28000  /  70018
# 30000  /  70018
# 32000  /  70018
# 34000  /  70018
# 36000  /  70018
# 38000  /  70018
# 40000  /  70018
# 42000  /  70018
# 44000  /  70018
# 46000  /  70018
# 48000  /  70018
# 50000  /  70018
# 52000  /  70018
# 54000  /  70018
# 56000  /  70018
# 58000  /  70018
# 60000  /  70018
# 62000  /  70018
# 64000  /  70018
# 66000  /  70018
# 68000  /  70018
# 70000  /  70018

# %%
raw_data_Y_train_encoded_a = np.zeros((np.shape(raw_data_Y_train_encoded)[0], y_train_size))
for i in range(np.shape(raw_data_Y_train_encoded)[0]):
    raw_data_Y_train_encoded_a[i] = raw_data_Y_train_encoded[i][0]
raw_data_Y_test_encoded_a = np.zeros((np.shape(raw_data_Y_test_encoded)[0], y_test_size))
for i in range(np.shape(raw_data_Y_test_encoded)[0]):
    raw_data_Y_test_encoded_a[i] = raw_data_Y_test_encoded[i][0]


print(np.shape(raw_data_X_train))
print(np.shape(raw_data_Y_train_encoded_a))
print(np.shape(raw_data_X_test))
print(np.shape(raw_data_Y_test_encoded_a))
# Out:
# (280076, 100, 48)
# (280076, 26)
# (70018, 100, 48)
# (70018, 26)

# %% [markdown]
# LSTM 모델링

# %%
#모델링 with LSTM
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, activation='relu', input_shape=(100, 48)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(26, activation='softmax'),
])
# Out:
# 2022-06-23 22:14:54.881514: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 128)               90624
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 26)                858
#
# ...
# Total params: 101,818
# Trainable params: 101,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# %%
import time
start_time = time.time()

# %%
model.fit(raw_data_X_train, raw_data_Y_train_encoded_a, epochs=20, batch_size=400) #20번 반복(epoch), 400회에 한 번 검사(batch_size)
print("Time: ", time.time() - start_time)
# Out:
# Epoch 1/20
# 701/701 [==============================] - 573s 809ms/step - loss: nan - acc: 0.0235
# Epoch 2/20
# 701/701 [==============================] - 534s 762ms/step - loss: nan - acc: 0.0235
# Epoch 3/20
# 701/701 [==============================] - 546s 779ms/step - loss: nan - acc: 0.0235
# Epoch 4/20
# 701/701 [==============================] - 580s 827ms/step - loss: nan - acc: 0.0235
# Epoch 5/20
# 701/701 [==============================] - 562s 802ms/step - loss: nan - acc: 0.0235
# Epoch 6/20
# 701/701 [==============================] - 514s 733ms/step - loss: nan - acc: 0.0235
# Epoch 7/20
# 701/701 [==============================] - 468s 667ms/step - loss: nan - acc: 0.0235
# Epoch 8/20
# 212/701 [========>.....................] - ETA: 7:46 - loss: nan - acc: 0.0229
